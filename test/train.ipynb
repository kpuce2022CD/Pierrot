# %% [markdown]
# #import
#  tracknet: test 폴더 안에 있는 코드

# %%
import cv2
import queue
import numpy
from PIL import Image, ImageDraw
from matplotlib import pyplot
from tracknet import trackNet
from collections import deque
import os
import tensorflow as tf

# %% [markdown]
# # 변수 정의 및 사전 작업

# %%
physical_devices = tf.config.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(physical_devices[0], True)

# 변수정의
current_frame = 0
tracknet_width, tracknet_height = 640, 360


# 영상불러오기 및 영상정보 추출
video = cv2.VideoCapture('/content/drive/MyDrive/test/video_cut.mp4')
fps = int(video.get(cv2.CAP_PROP_FPS))
frame_width = int(video.get(cv2.CAP_PROP_FRAME_WIDTH))
frame_height = int(video.get(cv2.CAP_PROP_FRAME_HEIGHT))
num_frames = int(video.get(cv2.CAP_PROP_FRAME_COUNT))

# 영상정보 출력
print('fps : {}'.format(fps))
print('frame sizee : {}x{}'.format(frame_width, frame_height))
print('num_frames :{}'.format(num_frames))

# 트렉넷 모델 불러오기 및 컴파일
modelFN = trackNet
model = modelFN(256, tracknet_height, tracknet_width)
model.compile(loss='categorical_crossentropy',
              optimizer='adadelta', metrics=['accuracy'])
model.load_weights("/content/drive/MyDrive/test/model.1")
# Out:
# fps : 60
# frame sizee : 1920x1080
# num_frames :929
# layer24 output shape: 256 360 640
# Model: "model_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 3, 360, 640)]     0
#
#  conv2d_54 (Conv2D)          (None, 64, 360, 640)      1792
#
#  activation_57 (Activation)  (None, 64, 360, 640)      0
#
#  batch_normalization_54 (Bat  (None, 64, 360, 640)     2560
#  chNormalization)
#
#  conv2d_55 (Conv2D)          (None, 64, 360, 640)      36928
#
#  activation_58 (Activation)  (None, 64, 360, 640)      0
#
#  batch_normalization_55 (Bat  (None, 64, 360, 640)     2560
#  chNormalization)
#
#  max_pooling2d_9 (MaxPooling  (None, 64, 180, 320)     0
#  2D)
#
#  conv2d_56 (Conv2D)          (None, 128, 180, 320)     73856
#
#  activation_59 (Activation)  (None, 128, 180, 320)     0
#
#  batch_normalization_56 (Bat  (None, 128, 180, 320)    1280
#  chNormalization)
#
#  conv2d_57 (Conv2D)          (None, 128, 180, 320)     147584
#
#  activation_60 (Activation)  (None, 128, 180, 320)     0
#
#  batch_normalization_57 (Bat  (None, 128, 180, 320)    1280
#  chNormalization)
#
#  max_pooling2d_10 (MaxPoolin  (None, 128, 90, 160)     0
#  g2D)
#
#  conv2d_58 (Conv2D)          (None, 256, 90, 160)      295168
#
#  activation_61 (Activation)  (None, 256, 90, 160)      0
#
#  batch_normalization_58 (Bat  (None, 256, 90, 160)     640
#  chNormalization)
#
#  conv2d_59 (Conv2D)          (None, 256, 90, 160)      590080
#
#  activation_62 (Activation)  (None, 256, 90, 160)      0
#
#  batch_normalization_59 (Bat  (None, 256, 90, 160)     640
#  chNormalization)
#
#  conv2d_60 (Conv2D)          (None, 256, 90, 160)      590080
#
#  activation_63 (Activation)  (None, 256, 90, 160)      0
#
#  batch_normalization_60 (Bat  (None, 256, 90, 160)     640
#  chNormalization)
#
#  max_pooling2d_11 (MaxPoolin  (None, 256, 45, 80)      0
#  g2D)
#
#  conv2d_61 (Conv2D)          (None, 512, 45, 80)       1180160
#
#  activation_64 (Activation)  (None, 512, 45, 80)       0
#
#  batch_normalization_61 (Bat  (None, 512, 45, 80)      320
#  chNormalization)
#
#  conv2d_62 (Conv2D)          (None, 512, 45, 80)       2359808
#
#  activation_65 (Activation)  (None, 512, 45, 80)       0
#
#  batch_normalization_62 (Bat  (None, 512, 45, 80)      320
#  chNormalization)
#
#  conv2d_63 (Conv2D)          (None, 512, 45, 80)       2359808
#
#  activation_66 (Activation)  (None, 512, 45, 80)       0
#
#  batch_normalization_63 (Bat  (None, 512, 45, 80)      320
#  chNormalization)
#
#  up_sampling2d_9 (UpSampling  (None, 512, 90, 160)     0
#  2D)
#
#  conv2d_64 (Conv2D)          (None, 256, 90, 160)      1179904
#
#  activation_67 (Activation)  (None, 256, 90, 160)      0
#
#  batch_normalization_64 (Bat  (None, 256, 90, 160)     640
#  chNormalization)
#
#  conv2d_65 (Conv2D)          (None, 256, 90, 160)      590080
#
#  activation_68 (Activation)  (None, 256, 90, 160)      0
#
#  batch_normalization_65 (Bat  (None, 256, 90, 160)     640
#  chNormalization)
#
#  conv2d_66 (Conv2D)          (None, 256, 90, 160)      590080
#
#  activation_69 (Activation)  (None, 256, 90, 160)      0
#
#  batch_normalization_66 (Bat  (None, 256, 90, 160)     640
#  chNormalization)
#
#  up_sampling2d_10 (UpSamplin  (None, 256, 180, 320)    0
#  g2D)
#
#  conv2d_67 (Conv2D)          (None, 128, 180, 320)     295040
#
#  activation_70 (Activation)  (None, 128, 180, 320)     0
#
#  batch_normalization_67 (Bat  (None, 128, 180, 320)    1280
#  chNormalization)
#
#  conv2d_68 (Conv2D)          (None, 128, 180, 320)     147584
#
#  activation_71 (Activation)  (None, 128, 180, 320)     0
#
#  batch_normalization_68 (Bat  (None, 128, 180, 320)    1280
#  chNormalization)
#
#  up_sampling2d_11 (UpSamplin  (None, 128, 360, 640)    0
#  g2D)
#
#  conv2d_69 (Conv2D)          (None, 64, 360, 640)      73792
#
#  activation_72 (Activation)  (None, 64, 360, 640)      0
#
#  batch_normalization_69 (Bat  (None, 64, 360, 640)     2560
#  chNormalization)
#
#  conv2d_70 (Conv2D)          (None, 64, 360, 640)      36928
#
#  activation_73 (Activation)  (None, 64, 360, 640)      0
#
#  batch_normalization_70 (Bat  (None, 64, 360, 640)     2560
#  chNormalization)
#
#  conv2d_71 (Conv2D)          (None, 256, 360, 640)     147712
#
#  activation_74 (Activation)  (None, 256, 360, 640)     0
#
#  batch_normalization_71 (Bat  (None, 256, 360, 640)    2560
#  chNormalization)
#
#  reshape_3 (Reshape)         (None, 256, 230400)       0
#
#  permute_3 (Permute)         (None, 230400, 256)       0
#
#  activation_75 (Activation)  (None, 230400, 256)       0
#
# =================================================================
# Total params: 10,719,104
# Trainable params: 10,707,744
# Non-trainable params: 11,360
# _________________________________________________________________

# %%
# 궤도를 그리기위한 프레임 7장 저장
trajectory_ball = deque()
for i in range(0, 8):
    trajectory_ball.appendleft(None)

# 공 좌표 저장을 위한 리스트
ball_coord_list = []

# 영상 저장을 위한 셋팅
fourcc = cv2.VideoWriter_fourcc(*'XVID')
output_video = cv2.VideoWriter(
    '/content/drive/MyDrive/test/video_output.mp4', fourcc, fps, (frame_width, frame_height))

# %% [markdown]
# # 영상 프레임 단위로 작업

# %%
# 프레임단위로 반복
while True:
    print('percentage of video processed : {}%'.format(round((current_frame/num_frames)*100)))

    # 프레임단위로 읽기
    # video.set(1, current_frame)
    ret, frame = video.read()

    if not ret:
        break

    # 프레임 사이즈 및 타입 수정을 위한 복사
    output_frame = frame

    # 프레임 사이즈 및 타임 수정
    frame = cv2.resize(frame, (tracknet_width, tracknet_height))
    frame = frame.astype(numpy.float32)

    # 아직 모름
    X = numpy.rollaxis(frame, 2, 0)

    # 히트맵 예측
    predict = model.predict(numpy.array([X]))[0]
    predict = predict.reshape(
        (tracknet_height, tracknet_width, 256)).argmax(axis=2)

    # cv2이미지 uint8로 변경해야만함
    predict = predict.astype(numpy.uint8)
    heatmap = cv2.resize(predict, (frame_width, frame_height))

    # 이미지 이진화작업 및 공 후보 트래킹 출력
    ret, heatmap = cv2.threshold(heatmap, 127, 255, cv2.THRESH_BINARY)
    circles = cv2.HoughCircles(heatmap, cv2.HOUGH_GRADIENT, dp=1,
                               minDist=1, param1=50, param2=2, minRadius=2, maxRadius=7)
    PIL_image = cv2.cvtColor(output_frame, cv2.COLOR_BGR2RGB)
    PIL_image = Image.fromarray(PIL_image)

    # 공후보 트래킹 성공 시 트래킹 표시
    if circles is not None:
        print("공후보 트랙킹 성공")
        # 공후보가 하나 일 시 트래킹 표시
        if len(circles) == 1:
            print("공후보 하나")
            x = int(circles[0][0][0])
            y = int(circles[0][0][1])

            trajectory_ball.appendleft([x, y])
            trajectory_ball.pop()
            ball_coord=[x, y]
            ball_coord_list.append(ball_coord)
            

        # 두 개 이상일 시 트래킹 표시하지 않음
        else:
            print("공후보 두개 이상")
            trajectory_ball.appendleft(None)
            trajectory_ball.pop()
    # 공 후보 트래킹 실패 시 트래킹 표시하지 않음
    else:
        trajectory_ball.appendleft(None)
        trajectory_ball.pop()

    # print("recent location of ball : {}x{}".format(
    #     int(trajectory_ball[0][0]), int(trajectory_ball[0][1])))

    # 전 7장의 프레임 후보공 draw
    for i in range(0, 8):
        if trajectory_ball[i] is not None:
            draw_x = trajectory_ball[i][0]
            draw_y = trajectory_ball[i][1]
            bbox = (draw_x - 2, draw_y-2, draw_x+2, draw_y+2)
            draw = ImageDraw.Draw(PIL_image)
            draw.ellipse(bbox, outline='yellow')
            del draw

    opencvImage = cv2.cvtColor(numpy.array(PIL_image), cv2.COLOR_RGB2BGR)
    output_video.write(opencvImage)
    current_frame += 1

    # cv2.imshow("Video", frame)
    # if cv2.waitKey(1) & 0xFF == 27:
    #     break
print(ball_coord_list)
video.release()
output_video.release()
cv2.destroyAllWindows
# Out:
# percentage of video processed : 0%
# percentage of video processed : 0%
# percentage of video processed : 0%
# percentage of video processed : 0%
# percentage of video processed : 0%
# percentage of video processed : 1%
# percentage of video processed : 1%
# percentage of video processed : 1%
# percentage of video processed : 1%
# percentage of video processed : 1%
# percentage of video processed : 1%
# percentage of video processed : 1%
# percentage of video processed : 1%
# percentage of video processed : 1%
# percentage of video processed : 2%
# percentage of video processed : 2%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 2%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 2%
# percentage of video processed : 2%
# percentage of video processed : 2%
# percentage of video processed : 2%
# percentage of video processed : 2%
# percentage of video processed : 2%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 2%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 3%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 3%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 3%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 3%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 3%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 3%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 3%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 3%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 3%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 4%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 4%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 4%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 4%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 4%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 4%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 4%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 4%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 4%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 5%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 5%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 5%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 5%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 5%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 5%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 5%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 5%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 5%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 5%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 6%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 6%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 6%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 6%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 6%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 6%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 6%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 6%
# percentage of video processed : 6%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 7%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 7%
# percentage of video processed : 7%
# percentage of video processed : 7%
# percentage of video processed : 7%
# percentage of video processed : 7%
# percentage of video processed : 7%
# percentage of video processed : 7%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 7%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 8%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 8%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 8%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 8%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 8%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 8%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 8%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 8%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 8%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 9%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 9%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 9%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 9%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 9%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 9%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 9%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 9%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 9%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 9%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 10%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 10%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 10%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 10%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 10%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 10%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 10%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 10%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 10%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 11%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 11%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 11%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 11%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 11%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 11%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 11%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 11%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 11%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 12%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 12%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 12%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 12%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 12%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 12%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 12%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 12%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 12%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 12%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 13%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 13%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 13%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 13%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 13%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 13%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 13%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 13%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 13%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 14%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 14%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 14%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 14%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 14%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 14%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 14%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 14%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 14%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 15%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 15%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 15%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 15%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 15%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 15%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 15%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 15%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 15%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 16%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 16%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 16%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 16%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 16%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 16%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 16%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 16%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 16%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 16%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 17%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 17%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 17%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 17%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 17%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 17%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 17%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 17%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 17%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 18%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 18%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 18%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 18%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 18%
# percentage of video processed : 18%
# percentage of video processed : 18%
# percentage of video processed : 18%
# percentage of video processed : 18%
# percentage of video processed : 19%
# percentage of video processed : 19%
# percentage of video processed : 19%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 19%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 19%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 19%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 19%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 19%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 19%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 19%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 20%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 20%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 20%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 20%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 20%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 20%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 20%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 20%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 20%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 21%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 21%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 21%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 21%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 21%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 21%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 21%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 21%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 21%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 22%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 22%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 22%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 22%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 22%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 22%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 22%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 22%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 22%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 22%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 23%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 23%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 23%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 23%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 23%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 23%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 23%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 23%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 23%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 24%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 24%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 24%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 24%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 24%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 24%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 24%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 24%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 24%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 25%
# percentage of video processed : 25%
# percentage of video processed : 25%
# percentage of video processed : 25%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 25%
# percentage of video processed : 25%
# percentage of video processed : 25%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 25%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 25%
# percentage of video processed : 26%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 26%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 26%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 26%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 26%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 26%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 26%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 26%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 26%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 26%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 27%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 27%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 27%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 27%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 27%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 27%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 27%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 27%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 27%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 28%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 28%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 28%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 28%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 28%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 28%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 28%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 28%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 28%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 29%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 29%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 29%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 29%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 29%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 29%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 29%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 29%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 29%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 29%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 30%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 30%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 30%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 30%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 30%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 30%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 30%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 30%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 30%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 31%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 31%
# percentage of video processed : 31%
# percentage of video processed : 31%
# percentage of video processed : 31%
# percentage of video processed : 31%
# percentage of video processed : 31%
# percentage of video processed : 31%
# percentage of video processed : 31%
# percentage of video processed : 32%
# percentage of video processed : 32%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 32%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 32%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 32%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 32%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 32%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 32%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 32%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 33%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 33%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 33%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 33%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 33%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 33%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 33%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 33%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 33%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 33%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 34%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 34%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 34%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 34%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 34%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 34%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 34%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 34%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 34%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 35%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 35%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 35%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 35%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 35%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 35%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 35%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 35%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 35%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 36%
# percentage of video processed : 36%
# percentage of video processed : 36%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 36%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 36%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 36%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 36%
# percentage of video processed : 36%
# percentage of video processed : 36%
# percentage of video processed : 36%
# percentage of video processed : 37%
# percentage of video processed : 37%
# percentage of video processed : 37%
# percentage of video processed : 37%
# percentage of video processed : 37%
# percentage of video processed : 37%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 37%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 37%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 37%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 38%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 38%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 38%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 38%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 38%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 38%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 38%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 38%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 38%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 39%
# percentage of video processed : 39%
# percentage of video processed : 39%
# percentage of video processed : 39%
# percentage of video processed : 39%
# percentage of video processed : 39%
# percentage of video processed : 39%
# percentage of video processed : 39%
# percentage of video processed : 39%
# percentage of video processed : 40%
# percentage of video processed : 40%
# percentage of video processed : 40%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 40%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 40%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 40%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 40%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 40%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 40%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 40%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 41%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 41%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 41%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 41%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 41%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 41%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 41%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 41%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 41%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 42%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 42%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 42%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 42%
# percentage of video processed : 42%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 42%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 42%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 42%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 42%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 43%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 43%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 43%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 43%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 43%
# percentage of video processed : 43%
# percentage of video processed : 43%
# percentage of video processed : 43%
# percentage of video processed : 43%
# percentage of video processed : 43%
# percentage of video processed : 44%
# percentage of video processed : 44%
# percentage of video processed : 44%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 44%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 44%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 44%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 44%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 44%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 44%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 45%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 45%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 45%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 45%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 45%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 45%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 45%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 45%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 45%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 46%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 46%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 46%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 46%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 46%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 46%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 46%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 46%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 46%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 47%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 47%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 47%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 47%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 47%
# percentage of video processed : 47%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 47%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 47%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 47%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 47%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 48%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 48%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 48%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 48%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 48%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 48%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 48%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 48%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 48%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 49%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 49%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 49%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 49%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 49%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 49%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 49%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 49%
# percentage of video processed : 49%
# percentage of video processed : 50%
# percentage of video processed : 50%
# percentage of video processed : 50%
# percentage of video processed : 50%
# percentage of video processed : 50%
# percentage of video processed : 50%
# percentage of video processed : 50%
# percentage of video processed : 50%
# percentage of video processed : 50%
# percentage of video processed : 50%
# percentage of video processed : 51%
# percentage of video processed : 51%
# percentage of video processed : 51%
# percentage of video processed : 51%
# percentage of video processed : 51%
# percentage of video processed : 51%
# percentage of video processed : 51%
# percentage of video processed : 51%
# percentage of video processed : 51%
# percentage of video processed : 52%
# percentage of video processed : 52%
# percentage of video processed : 52%
# percentage of video processed : 52%
# percentage of video processed : 52%
# percentage of video processed : 52%
# percentage of video processed : 52%
# percentage of video processed : 52%
# percentage of video processed : 52%
# percentage of video processed : 53%
# percentage of video processed : 53%
# percentage of video processed : 53%
# percentage of video processed : 53%
# percentage of video processed : 53%
# percentage of video processed : 53%
# percentage of video processed : 53%
# percentage of video processed : 53%
# percentage of video processed : 53%
# percentage of video processed : 53%
# percentage of video processed : 54%
# percentage of video processed : 54%
# percentage of video processed : 54%
# percentage of video processed : 54%
# percentage of video processed : 54%
# percentage of video processed : 54%
# percentage of video processed : 54%
# percentage of video processed : 54%
# percentage of video processed : 54%
# percentage of video processed : 55%
# percentage of video processed : 55%
# percentage of video processed : 55%
# percentage of video processed : 55%
# percentage of video processed : 55%
# percentage of video processed : 55%
# percentage of video processed : 55%
# percentage of video processed : 55%
# percentage of video processed : 55%
# percentage of video processed : 56%
# percentage of video processed : 56%
# percentage of video processed : 56%
# percentage of video processed : 56%
# percentage of video processed : 56%
# percentage of video processed : 56%
# percentage of video processed : 56%
# percentage of video processed : 56%
# percentage of video processed : 56%
# percentage of video processed : 57%
# percentage of video processed : 57%
# percentage of video processed : 57%
# percentage of video processed : 57%
# percentage of video processed : 57%
# percentage of video processed : 57%
# percentage of video processed : 57%
# percentage of video processed : 57%
# percentage of video processed : 57%
# percentage of video processed : 57%
# percentage of video processed : 58%
# percentage of video processed : 58%
# percentage of video processed : 58%
# percentage of video processed : 58%
# percentage of video processed : 58%
# percentage of video processed : 58%
# percentage of video processed : 58%
# percentage of video processed : 58%
# percentage of video processed : 58%
# percentage of video processed : 59%
# percentage of video processed : 59%
# percentage of video processed : 59%
# percentage of video processed : 59%
# percentage of video processed : 59%
# percentage of video processed : 59%
# percentage of video processed : 59%
# percentage of video processed : 59%
# percentage of video processed : 59%
# percentage of video processed : 60%
# percentage of video processed : 60%
# percentage of video processed : 60%
# percentage of video processed : 60%
# percentage of video processed : 60%
# percentage of video processed : 60%
# percentage of video processed : 60%
# percentage of video processed : 60%
# percentage of video processed : 60%
# percentage of video processed : 60%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 61%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 61%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 61%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 61%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 61%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 61%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 61%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 61%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 61%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 62%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 62%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 62%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 62%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 62%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 62%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 62%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 62%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 62%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 63%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 63%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 63%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 63%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 63%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 63%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 63%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 63%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 63%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 64%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 64%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 64%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 64%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 64%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 64%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 64%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 64%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 64%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 64%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 65%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 65%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 65%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 65%
# percentage of video processed : 65%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 65%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 65%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 65%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 65%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 66%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 66%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 66%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 66%
# percentage of video processed : 66%
# percentage of video processed : 66%
# percentage of video processed : 66%
# percentage of video processed : 66%
# percentage of video processed : 66%
# percentage of video processed : 67%
# percentage of video processed : 67%
# percentage of video processed : 67%
# percentage of video processed : 67%
# percentage of video processed : 67%
# percentage of video processed : 67%
# percentage of video processed : 67%
# percentage of video processed : 67%
# percentage of video processed : 67%
# percentage of video processed : 67%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 68%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 68%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 68%
# percentage of video processed : 68%
# percentage of video processed : 68%
# percentage of video processed : 68%
# percentage of video processed : 68%
# percentage of video processed : 68%
# percentage of video processed : 68%
# percentage of video processed : 69%
# percentage of video processed : 69%
# percentage of video processed : 69%
# percentage of video processed : 69%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 69%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 69%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 69%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 69%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 69%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 70%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 70%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 70%
# percentage of video processed : 70%
# percentage of video processed : 70%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 70%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 70%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 70%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 70%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 71%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 71%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 71%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 71%
# percentage of video processed : 71%
# percentage of video processed : 71%
# percentage of video processed : 71%
# percentage of video processed : 71%
# percentage of video processed : 71%
# percentage of video processed : 71%
# percentage of video processed : 72%
# percentage of video processed : 72%
# percentage of video processed : 72%
# percentage of video processed : 72%
# percentage of video processed : 72%
# percentage of video processed : 72%
# percentage of video processed : 72%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 72%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 72%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 73%
# percentage of video processed : 73%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 73%
# percentage of video processed : 73%
# percentage of video processed : 73%
# percentage of video processed : 73%
# percentage of video processed : 73%
# percentage of video processed : 73%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 73%
# percentage of video processed : 74%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 74%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 74%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 74%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 74%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 74%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 74%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 74%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 74%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 74%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 75%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 75%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 75%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 75%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 75%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 75%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 75%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 75%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 75%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 76%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 76%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 76%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 76%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 76%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 76%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 76%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 76%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 76%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 77%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 77%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 77%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 77%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 77%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 77%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 77%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 77%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 77%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 78%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 78%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 78%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 78%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 78%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 78%
# percentage of video processed : 78%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 78%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 78%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 78%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 79%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 79%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 79%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 79%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 79%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 79%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 79%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 79%
# percentage of video processed : 79%
# percentage of video processed : 80%
# percentage of video processed : 80%
# percentage of video processed : 80%
# percentage of video processed : 80%
# percentage of video processed : 80%
# percentage of video processed : 80%
# percentage of video processed : 80%
# percentage of video processed : 80%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 80%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 81%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 81%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 81%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 81%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 81%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 81%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 81%
# percentage of video processed : 81%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 81%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 81%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 82%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 82%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 82%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 82%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 82%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 82%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 82%
# percentage of video processed : 82%
# percentage of video processed : 82%
# percentage of video processed : 83%
# percentage of video processed : 83%
# percentage of video processed : 83%
# percentage of video processed : 83%
# percentage of video processed : 83%
# percentage of video processed : 83%
# percentage of video processed : 83%
# percentage of video processed : 83%
# percentage of video processed : 83%
# percentage of video processed : 84%
# percentage of video processed : 84%
# percentage of video processed : 84%
# percentage of video processed : 84%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 84%
# percentage of video processed : 84%
# percentage of video processed : 84%
# percentage of video processed : 84%
# percentage of video processed : 84%
# percentage of video processed : 84%
# percentage of video processed : 85%
# percentage of video processed : 85%
# percentage of video processed : 85%
# percentage of video processed : 85%
# percentage of video processed : 85%
# percentage of video processed : 85%
# percentage of video processed : 85%
# percentage of video processed : 85%
# percentage of video processed : 85%
# percentage of video processed : 86%
# percentage of video processed : 86%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 86%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 86%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 86%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 86%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 86%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 86%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 86%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 87%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 87%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 87%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 87%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 87%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 87%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 87%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 87%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 87%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 88%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 88%
# percentage of video processed : 88%
# percentage of video processed : 88%
# percentage of video processed : 88%
# percentage of video processed : 88%
# percentage of video processed : 88%
# percentage of video processed : 88%
# percentage of video processed : 88%
# percentage of video processed : 88%
# percentage of video processed : 89%
# percentage of video processed : 89%
# percentage of video processed : 89%
# percentage of video processed : 89%
# percentage of video processed : 89%
# percentage of video processed : 89%
# percentage of video processed : 89%
# percentage of video processed : 89%
# percentage of video processed : 89%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 90%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 90%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 90%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 90%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 90%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 90%
# percentage of video processed : 90%
# percentage of video processed : 90%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 90%
# percentage of video processed : 91%
# percentage of video processed : 91%
# percentage of video processed : 91%
# percentage of video processed : 91%
# percentage of video processed : 91%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 91%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 91%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 91%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 91%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 91%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 92%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 92%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 92%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 92%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 92%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 92%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 92%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 92%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 92%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 93%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 93%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 93%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 93%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 93%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 93%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 93%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 93%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 93%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 94%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 94%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 94%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 94%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 94%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 94%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 94%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 94%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 94%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 95%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 95%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 95%
# percentage of video processed : 95%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 95%
# percentage of video processed : 95%
# percentage of video processed : 95%
# percentage of video processed : 95%
# percentage of video processed : 95%
# percentage of video processed : 95%
# percentage of video processed : 96%
# percentage of video processed : 96%
# percentage of video processed : 96%
# percentage of video processed : 96%
# percentage of video processed : 96%
# percentage of video processed : 96%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 96%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 96%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 96%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 97%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 97%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 97%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 97%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 97%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 97%
# 공후보 트랙킹 성공
# 공후보 하나
# percentage of video processed : 97%
# percentage of video processed : 97%
# percentage of video processed : 97%
# percentage of video processed : 98%
# percentage of video processed : 98%
# percentage of video processed : 98%
# percentage of video processed : 98%
# percentage of video processed : 98%
# percentage of video processed : 98%
# percentage of video processed : 98%
# percentage of video processed : 98%
# percentage of video processed : 98%
# percentage of video processed : 98%
# percentage of video processed : 99%
# percentage of video processed : 99%
# percentage of video processed : 99%
# percentage of video processed : 99%
# percentage of video processed : 99%
# percentage of video processed : 99%
# percentage of video processed : 99%
# percentage of video processed : 99%
# percentage of video processed : 99%
# percentage of video processed : 100%
# percentage of video processed : 100%
# [[985, 325], [978, 345], [1098, 238], [921, 555], [918, 574], [918, 574], [904, 613], [895, 644], [886, 649], [877, 654], [870, 658], [870, 658], [861, 664], [853, 672], [846, 679], [837, 688], [827, 695], [827, 695], [821, 707], [812, 716], [803, 729], [1051, 313], [786, 755], [786, 755], [782, 769], [782, 746], [786, 730], [793, 700], [800, 677], [800, 677], [803, 656], [807, 640], [814, 620], [819, 593], [819, 579], [819, 579], [825, 562], [831, 546], [834, 532], [833, 805], [833, 805], [865, 427], [867, 418], [871, 409], [872, 400], [877, 392], [877, 392], [877, 385], [883, 377], [883, 369], [887, 366], [890, 358], [890, 357], [892, 352], [894, 346], [897, 340], [898, 336], [900, 332], [900, 332], [902, 329], [905, 325], [905, 322], [908, 320], [910, 316], [910, 316], [912, 315], [914, 314], [916, 310], [919, 308], [919, 306], [919, 306], [920, 305], [924, 306], [922, 306], [926, 305], [928, 305], [926, 307], [930, 306], [930, 305], [932, 305], [933, 307], [935, 310], [935, 308], [936, 310], [937, 313], [938, 314], [940, 316], [942, 319], [942, 319], [942, 322], [943, 323], [945, 324], [946, 316], [945, 306], [945, 306], [945, 298], [946, 291], [947, 284], [947, 278], [950, 272], [949, 273], [950, 266], [951, 261], [950, 255], [950, 251], [951, 245], [951, 245], [953, 241], [952, 237], [950, 236], [945, 237], [939, 240], [938, 239], [934, 242], [928, 244], [922, 250], [917, 252], [911, 256], [911, 256], [905, 263], [899, 267], [896, 274], [890, 278], [883, 286], [883, 286], [878, 293], [873, 300], [869, 309], [863, 318], [858, 329], [858, 329], [851, 338], [846, 349], [840, 359], [835, 371], [830, 384], [830, 384], [825, 397], [818, 410], [812, 424], [774, 535], [773, 537], [768, 550], [761, 572], [754, 592], [750, 615], [748, 624], [748, 624], [739, 652], [733, 674], [728, 698], [727, 718], [718, 733], [718, 733], [714, 732], [709, 729], [705, 728], [702, 729], [694, 728], [696, 728], [692, 728], [688, 730], [684, 730], [678, 731], [675, 734], [675, 734], [673, 737], [667, 741], [664, 743], [659, 749], [653, 755], [653, 755], [650, 759], [647, 765], [642, 774], [636, 780], [633, 786], [633, 787], [630, 796], [625, 804], [629, 769], [634, 737], [633, 718], [633, 718], [640, 697], [644, 657], [649, 640], [651, 616], [655, 592], [654, 591], [654, 578], [656, 560], [659, 544], [662, 525], [668, 482], [675, 448], [675, 448], [677, 427], [677, 419], [678, 410], [678, 404], [678, 404], [679, 394], [682, 394], [682, 385], [682, 380], [683, 374], [683, 374], [684, 370], [684, 367], [684, 364], [685, 361], [686, 359], [686, 359], [686, 357], [686, 356], [687, 353], [686, 353], [687, 352], [687, 352], [688, 350], [687, 339], [685, 329], [687, 318], [686, 309], [687, 309], [681, 300], [686, 293], [688, 283], [689, 273], [688, 268], [689, 270], [689, 261], [688, 256], [688, 250], [689, 243], [688, 238], [688, 238], [690, 237], [690, 231], [690, 228], [691, 226], [696, 227], [699, 226], [705, 227], [758, 234], [758, 234], [762, 239], [769, 241], [775, 243], [780, 246], [787, 250], [787, 250], [793, 253], [800, 256], [806, 261], [812, 263], [820, 266], [820, 266], [826, 271], [832, 274], [840, 279], [845, 283], [851, 289], [852, 289], [858, 296], [866, 299], [874, 306], [879, 312], [888, 318], [888, 318], [893, 323], [900, 330], [908, 338], [914, 344], [922, 350], [922, 350], [928, 360], [937, 367], [945, 378], [950, 384], [967, 402], [974, 411], [980, 421], [989, 428], [1054, 518], [1061, 533], [1066, 543], [1076, 557], [1077, 558], [1087, 569], [1093, 585], [1101, 601], [1110, 614], [1119, 629], [1119, 629], [1128, 642], [1136, 662], [1211, 723], [1216, 718], [1220, 719], [1226, 719], [1227, 718], [1232, 718], [1238, 719], [1243, 721], [1252, 721], [1256, 721], [1256, 721], [1262, 725], [1268, 728], [1273, 731], [1280, 734], [1286, 737], [1286, 737], [1293, 742], [1298, 746], [1305, 749], [1299, 691], [1299, 691], [1295, 668], [1295, 649], [1288, 623], [1285, 597], [1280, 571], [1280, 571], [1277, 552], [1254, 430], [1249, 417], [1249 ...
# <function destroyAllWindows>

# %% [markdown]
# #colab 사용을 위한 사전 작업

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import sys
sys.path.append('/content/drive/My Drive/test')
print(sys.path)
# Out:
# ['', '/content', '/env/python', '/usr/lib/python37.zip', '/usr/lib/python3.7', '/usr/lib/python3.7/lib-dynload', '/usr/local/lib/python3.7/dist-packages', '/usr/lib/python3/dist-packages', '/usr/local/lib/python3.7/dist-packages/IPython/extensions', '/root/.ipython', '/content/drive/My Drive/test']

# %% [markdown]
# # 새 섹션

# %% [markdown]
# # 새 섹션
